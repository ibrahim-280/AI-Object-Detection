# %% [markdown]
# <a href="https://colab.research.google.com/github/ibrahim-280/AI-Object-Detection/blob/main/3d_model_influencer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install diffusers transformers accelerate safetensors xformers opencv-python matplotlib
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %%
import torch
print("Torch version:", torch.__version__)
print("Torchvision version:", torch.__version__)
print("GPU available:", torch.cuda.is_available())
print("GPU Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# Torch version: 2.6.0+cu118
# Torchvision version: 2.6.0+cu118
# GPU available: True
# GPU Name: Tesla T4

# %%
from diffusers import StableDiffusionPipeline
import torch

pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5").to("cuda")
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# ...

# %%
prompts = [
    "photo of a young woman with long brown hair, black eyes, fair skin, wearing a modern outfit with a smile, consistent features",
    "photo of a young woman with long brown hair, black eyes, fair skin, wearing a modern outfit with a smile, consistent features",
    "photo of a young woman with long brown hair, black eyes, fair skin, wearing a modern outfit with a smile, consistent features"
]

images = [pipe(prompt).images[0] for prompt in prompts]

# Display the images to check consistency
for img in images:
    plt.imshow(img)
    plt.axis("off")
    plt.show()
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "Ultra-realistic portrait of a young woman with long straight brown hair, green eyes, fair skin, oval face, full lips, sharp nose, wearing a simple, modern, stylish outfit, soft lighting, hyper-detailed, professional studio look"

images = [pipe(prompt).images[0] for prompt in prompts]

# Display the images to check consistency
for img in images:
    plt.imshow(img)
    plt.axis("off")
    plt.show()
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
